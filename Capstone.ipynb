# %%
import numpy as np
import pandas as pd

# %%
countries = pd.read_csv("countries.csv", sep = ";")
countries
# Out:
#             Country Area(sq km) Birth rate(births/1000 population)  \
# 0            String      double                             double
# 1       Afghanistan      647500                              47.02
# 2          Akrotiri         123                                NaN
# 3           Albania       28748                              15.08
# 4           Algeria     2381740                              17.13
# ..              ...         ...                                ...
# 259       West Bank        5860                              32.37
# 260  Western Sahara      266000                                NaN
# 261           Yemen      527970                              43.07
# 262          Zambia      752614                              41.38
# 263        Zimbabwe      390580                              29.74
#
#     Current account balance Death rate(deaths/1000 population)  \
# 0                    double                             double
# ...

# %%
countries.columns
# Out:
# Index(['Country', 'Area(sq km)', 'Birth rate(births/1000 population)',
#        'Current account balance', 'Death rate(deaths/1000 population)',
#        'Debt - external', 'Electricity - consumption(kWh)',
#        'Electricity - production(kWh)', 'Exports', 'GDP', 'GDP - per capita',
#        'GDP - real growth rate(%)', 'HIV/AIDS - adult prevalence rate(%)',
#        'HIV/AIDS - deaths', 'HIV/AIDS - people living with HIV/AIDS',
#        'Highways(km)', 'Imports', 'Industrial production growth rate(%)',
#        'Infant mortality rate(deaths/1000 live births)',
#        'Inflation rate (consumer prices)(%)', 'Internet hosts',
#        'Internet users', 'Investment (gross fixed)(% of GDP)', 'Labor force',
#        'Life expectancy at birth(years)',
#        'Military expenditures - dollar figure',
#        'Military expenditures - percent of GDP(%)',
#        'Natural gas - consumption(cu m)', 'Natural gas - exports(cu m)',
# ...

# %%
compare_gdp = countries[["Country", "GDP - per capita", "Birth rate(births/1000 population)", "Death rate(deaths/1000 population)", 
                        "Electricity - consumption(kWh)", "Highways(km)", "Infant mortality rate(deaths/1000 live births)",
                        "Internet users", "Life expectancy at birth(years)", "Military expenditures - percent of GDP(%)",
                        "Telephones - mobile cellular", "Total fertility rate(children born/woman)"]]

compare_gdp
# Out:
#             Country GDP - per capita Birth rate(births/1000 population)  \
# 0            String           double                             double
# 1       Afghanistan              800                              47.02
# 2          Akrotiri              NaN                                NaN
# 3           Albania             4900                              15.08
# 4           Algeria             6600                              17.13
# ..              ...              ...                                ...
# 259       West Bank              800                              32.37
# 260  Western Sahara              NaN                                NaN
# 261           Yemen              800                              43.07
# 262          Zambia              900                              41.38
# 263        Zimbabwe             1900                              29.74
#
#     Death rate(deaths/1000 population) Electricity - consumption(kWh)  \
# ...

# %%
no_na = compare_gdp.dropna()
no_na
# Out:
#          Country GDP - per capita Birth rate(births/1000 population)  \
# 0         String           double                             double
# 1    Afghanistan              800                              47.02
# 3        Albania             4900                              15.08
# 4        Algeria             6600                              17.13
# 7         Angola             2100                              44.64
# ..           ...              ...                                ...
# 254    Venezuela             5800                              18.91
# 255      Vietnam             2700                              17.07
# 261        Yemen              800                              43.07
# 262       Zambia              900                              41.38
# 263     Zimbabwe             1900                              29.74
#
#     Death rate(deaths/1000 population) Electricity - consumption(kWh)  \
# ...

# %%
compare_gdp_clean = no_na.drop(0, axis = 0)
compare_gdp_clean
# Out:
#          Country GDP - per capita Birth rate(births/1000 population)  \
# 1    Afghanistan              800                              47.02
# 3        Albania             4900                              15.08
# 4        Algeria             6600                              17.13
# 7         Angola             2100                              44.64
# 11     Argentina            12400                              16.90
# ..           ...              ...                                ...
# 254    Venezuela             5800                              18.91
# 255      Vietnam             2700                              17.07
# 261        Yemen              800                              43.07
# 262       Zambia              900                              41.38
# 263     Zimbabwe             1900                              29.74
#
#     Death rate(deaths/1000 population) Electricity - consumption(kWh)  \
# ...

# %%
new_gdp = compare_gdp_clean['GDP - per capita'].astype('int')
new_gdp
# Out:
# 1        800
# 3       4900
# 4       6600
# 7       2100
# 11     12400
#        ...
# 254     5800
# 255     2700
# 261      800
# 262      900
# 263     1900
# Name: GDP - per capita, Length: 163, dtype: int32

# %%
new_gdp.sort_values("GDP - per capita")
# Out:
# C:\Users\seren\AppData\Local\Temp\ipykernel_10712\3684745774.py:1: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   new_gdp.sort_values("GDP - per capita")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'GDP - per capita'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 new_gdp.sort_values("GDP - per capita")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...
